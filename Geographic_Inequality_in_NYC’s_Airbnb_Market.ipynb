# %%
from google.colab import files
import pandas as pd

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

  # Assuming the uploaded file is a CSV, you can read it into a pandas DataFrame
  # Replace 'your_file_name.csv' with the actual name of your uploaded file
  # For this example, we'll use the first uploaded file name
  try:
    df = pd.read_csv(fn)
    print(f"Successfully loaded '{fn}' into a pandas DataFrame.")
    display(df.head())
  except Exception as e:
    print(f"Error reading '{fn}' as CSV: {e}")
# Out:
#      <input type="file" id="files-c37f2389-9679-4988-b797-333641d50422" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c37f2389-9679-4988-b797-333641d50422">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install datascience

from datascience import *
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# !pip install datascience

# %%
from datascience import *
import numpy as np
airbnb = Table().read_table("AB_NYC_2019.csv")
airbnb.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>id</th> <th>name</th> <th>host_id</th> <th>host_name</th> <th>neighbourhood_group</th> <th>neighbourhood</th> <th>latitude</th> <th>longitude</th> <th>room_type</th> <th>price</th> <th>minimum_nights</th> <th>number_of_reviews</th> <th>last_review</th> <th>reviews_per_month</th> <th>calculated_host_listings_count</th> <th>availability_365</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>2539</td> <td>Clean & quiet apt home by the park              </td> <td>2787   </td> <td>John       </td> <td>Brooklyn           </td> <td>Kensington   </td> <td>40.6475 </td> <td>-73.9724 </td> <td>Private room   </td> <td>149  </td> <td>1             </td> <td>9                </td> <td>2018-10-19 </td> <td>0.21             </td> <td>6                             </td> <td>365             </td>
#         </tr>
#         <tr>
# ...

# %%
airbnb= airbnb.where("price", are.above(0)).where("price", are.below(2000))

# %%
airbnb_by_loc= airbnb.select("name", "neighbourhood_group","neighbourhood","price","number_of_reviews","last_review")
airbnb_by_loc.show(10)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>name</th> <th>neighbourhood_group</th> <th>neighbourhood</th> <th>price</th> <th>number_of_reviews</th> <th>last_review</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Clean & quiet apt home by the park              </td> <td>Brooklyn           </td> <td>Kensington        </td> <td>149  </td> <td>9                </td> <td>2018-10-19 </td>
#         </tr>
#         <tr>
#             <td>Skylit Midtown Castle                           </td> <td>Manhattan          </td> <td>Midtown           </td> <td>225  </td> <td>45               </td> <td>2019-05-21 </td>
#         </tr>
#         <tr>
#             <td>THE VILLAGE OF HARLEM....NEW YORK !             </td> <td>Manhattan          </td> <td>Harlem            </td> <td>150  </td> <td>0                </td> <td>nan        </td>
#         </tr>
#         <tr>
# ...

# %%
airbnb_by_loc = airbnb_by_loc.sort("price", descending=True)

# %%
avg_price_by_borough = airbnb_by_loc.group("neighbourhood_group", np.mean)
avg_price_by_borough.show()
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>neighbourhood_group</th> <th>name mean</th> <th>neighbourhood mean</th> <th>price mean</th> <th>number_of_reviews mean</th> <th>last_review mean</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Bronx              </td> <td>         </td> <td>                  </td> <td>85.3618   </td> <td>26.0018               </td> <td>                </td>
#         </tr>
#         <tr>
#             <td>Brooklyn           </td> <td>         </td> <td>                  </td> <td>119.722   </td> <td>24.2241               </td> <td>                </td>
#         </tr>
#         <tr>
#             <td>Manhattan          </td> <td>         </td> <td>                  </td> <td>184.189   </td> <td>21.0438               </td> <td>                </td>
#         </tr>
#         <tr>
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert the datascience Table to a pandas DataFrame for easier plotting with seaborn
avg_price_by_borough_df = avg_price_by_borough.to_df()

plt.figure(figsize=(10, 6))
sns.barplot(x='neighbourhood_group', y='price mean', data=avg_price_by_borough_df, palette='viridis', hue='neighbourhood_group', legend=False)
plt.title('Average Price by Neighborhood Group')
plt.xlabel('Neighborhood Group')
plt.ylabel('Average Price')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# This bar chart shows the average Airbnb price across NYC boroughs. Airbnb prices in NYC are heavily concentrated in Manhattan, with significantly higher averages than other boroughs. This suggests that short-term rental markets are strongly shaped by location and demand. The disparity highlights how economic activity and tourism drive pricing, reinforcing existing geographic inequalities within the city.

# %%
import matplotlib.pyplot as plt

df_clean = df[df["price"] < 1000]

plt.figure()
df_clean.boxplot(column="price", by="neighbourhood_group")

plt.title("Price Distribution by Borough")
plt.suptitle("")  # removes default weird title
plt.xlabel("Borough")
plt.ylabel("Price")

plt.show()

# %% [markdown]
# The box plot reveals clear differences in Airbnb price distributions across NYC boroughs. Manhattan has the highest median price as well as the largest interquartile range, indicating both higher typical prices and greater variability. Additionally, Manhattan and Brooklyn exhibit a larger number of high-price outliers, suggesting the presence of many premium or luxury listings. In contrast, the Bronx, Queens, and Staten Island have lower median prices and fewer outliers, reflecting more consistent and generally lower-cost listings. Overall, this highlights not only differences in average pricing, but also disparities in price distribution and market segmentation across boroughs.
